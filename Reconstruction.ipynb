542149644707269, 0.44494028619636306], 'I': [0.0, 1.0, 0.9885681993705422, 0.6916893496569098, 0.716811876392177, 0.8904204716744661, 0.6644952019940336, 0.8546040454511806, 0.6913489478662816, 0.9061621665512967, 0.7032972461385075, 0.7838413537916215, 0.6408050606795745, 0.7634954867765327, 0.8904188104131613], 'L': [0.0, 0.5863803144325149, 1.0, 0.4159670626311591, 0.5589965160251994, 0.5314191618685169, 0.6273477703452663, 0.6163358349171919, 0.6702660421447921, 0.735795072378089, 0.838109980309614, 0.685712646619566, 0.6476918286577013, 0.6418595735475899, 0.5893267664779259], 'K': [1.0, 0.0, 0.6224925689412456, 0.45870440453940453, 0.28653953182045644, 0.5702684748742254, 0.7109431777333735, 0.4731589744266013, 0.5944542049205196, 0.8774963904168196, 0.4232781906968988, 0.47385438071969777, 0.468590598677312, 0.654037749694505, 0.4283132649572589], 'M': [0.0, 0.43830909825218134, 0.7409924383569062, 0.7752214270749493, 0.9899826728151006, 0.6396972425149291, 1.0, 0.8187826178008332, 0.6091062409752325, 0.5341964995888923, 0.5133901381085172, 0.9538346486338766, 0.6032724826669291, 0.8040070758905902, 0.7631196336148462], 'F': [0.0, 0.895733473148773, 0.7011590523747511, 0.7376751135070108, 0.8326948911199726, 0.6656336257964081, 0.8350784673036493, 0.9640613943974748, 0.8036733026826525, 0.7859090504395838, 1.0, 0.9471968615621887, 0.866915547211168, 0.7070806796148316, 0.5571209609523142], 'P': [1.0, 0.9678299346937969, 0.2873103002501223, 0.0, 0.7213204128707134, 0.666959615954362 ...
# dict

# %% [markdown]
# Calculate distance

# %%
dat.shape
# Out:
# (29695, 19, 15)

# %%
#
sample=dat[:10000]
sample[1].shape
# Out:
# (19, 15)

# %%
len(sample)
# Out:
# 100

# %%
seq=sample[1][0]
from scipy.spatial import distance
distance.euclidean(newdic['N'], seq)
# Out:
# 1.6620416942409277

# %%
# Out:
# ['A',
#  'R',
#  'N',
#  'D',
#  'C',
#  'E',
#  'Q',
#  'G',
#  'H',
#  'I',
#  'L',
#  'K',
#  'M',
#  'F',
#  'P',
#  'S',
#  'T',
#  'W',
#  'Y',
#  'V']

# %%
from IPython.core.display import display_pretty
seq=sample[1][0]
from scipy.spatial import distance

def cal_distance(dict,seq):
  dist=[]
  index_code=list(dict.keys())

  seq_decode = ''
  for i in range(len(seq)):
    m1=seq[i] # each row w
    if max(m1) <= 0.1:
      continue 
    for key, value in dict.items():
      a1=dict[key]
      dist.append(distance.euclidean(dict[key], m1))

    seq_decode+=index_code[np.argmax(dist)]
  return seq_decode

# %%
sample[1][0]
# Out:
# array([0.00164328, 0.7478904 , 0.0805108 , 0.9984883 , 0.76167965,
#        0.8150803 , 0.43347472, 0.16906214, 0.3319984 , 0.57055247,
#        0.48174757, 0.3912905 , 0.43094915, 0.37598193, 0.34417993],
#       dtype=float32)

# %%
def cal_distance(dict,seq):
  dist=[]
  index_code=list(dict.keys())
  
  for key, value in dict.items():
    a1=dict[key]
    dist.append(distance.euclidean(dict[key], seq))
  print(dist,'\n',index_code,'\n',np.argmin(dist))
  return index_code[np.argmin(dist)]

def code_seq(dict, mat):
  indexcode= ''

  for i in range(len(mat)):
    m1 = mat[i]
    value_max= np.max(m1)
    if value_max <= 0.1:
      continue
    indexcode+=cal_distance(newdic,m1)
  return indexcode

# %%
cal_distance(newdic,dat[18000][0])
time = 10
for i in range(time):
  cal_distance(newdic,dat[i][5])
# Out:
# [1.85370334786561, 1.6666525572729582, 1.662836896178565, 1.5814770610925557, 0.0047595317978336195, 1.6741205760114963, 1.590926860070447, 1.585363194859957, 1.4172159684554797, 1.566300915355485, 1.4514118611961344, 1.6909150732087401, 1.4811491631648064, 1.5775191302110223, 1.5559164191541495, 1.6617523601216615, 1.6374282030592051, 1.1433541579505537, 1.3029340883515557, 1.302050521437216]
#  ['A', 'R', 'N', 'D', 'C', 'E', 'Q', 'G', 'H', 'I', 'L', 'K', 'M', 'F', 'P', 'S', 'T', 'W', 'Y', 'V']
#  4
# [1.2614838030130031, 1.1317111714867998, 0.9251964404796615, 0.7941558095948558, 1.27447917166706, 0.9848648353761443, 0.9732272276882438, 0.7572196641657346, 1.2043356673934278, 1.6710949017384442, 1.2734428464608605, 0.9811496718706995, 1.5907475041429087, 1.7292928112371164, 1.0028842637788427, 0.6554020027721255, 1.0174286870285827, 1.372798478535399, 1.2580049200603596, 1.329379302183149]
#  ['A', 'R', 'N', 'D', 'C', 'E', 'Q', 'G', 'H', 'I', 'L', 'K', 'M', 'F', 'P', 'S', 'T', 'W', 'Y', 'V']
#  15
# [1.2614363330197527, 1.1295416627724055, 0.924600449245092, 0.7925331566576631, 1.2773661267038818, 0.9832376112081406, 0.9713701443583722, 0.7582976226923337, 1.2057655434814458, 1.674801181367919, 1.276440086422533, 0.979769761685545, 1.5938807609618022, 1.7326543418412435, 1.0034756035824526, 0.652635825647478, 1.0162470271986839, 1.3747378121907943, 1.2597999111621117, 1.3329228414552021]
#  ['A', 'R', 'N', 'D', 'C', 'E', 'Q', 'G', 'H', 'I', 'L', 'K', 'M', 'F', 'P', 'S', 'T', 'W', 'Y', 'V']
#  15
# [1.265362997997919, 1.123684913806344, 0.9278707569903891, 0.7970679308555519, 1.2736955357693611, 0.9788909796044053, 0.965327072988433, 0.7658064766090693, 1.2017457240185299, 1.6655850238192074, 1.2674635314229232, 0.972733554367672, 1.5849775130830472, 1.723118875428841, 1.0000706790136578, 0.6590590823608498, 1.0162950427784025, 1.366775293239042, 1.252566022525843, 1.325016378992154]
#  ['A', 'R', 'N', 'D', 'C', 'E', 'Q', 'G', 'H', 'I', 'L', 'K', 'M', 'F', 'P', 'S', 'T', 'W', 'Y', 'V']
#  15
# [1.261945453811027, 1.1305769579102247, 0.9245358638756473, 0.793842033722561, 1.2801586619664358, 0.9862979350755651, 0.9743921319455301, 0.7548491808828326, 1.2087857144626193, 1.67686459968817, 1.2785995725771275, 0.9818931336102309, 1.596985289162197, 1.7349766869674055, 1.0041332453751437, 0.6501247735498525, 1.0158519048147316, 1.3771260319970917, 1.2608588643308232, 1.3348123825120295]
#  ['A', 'R', 'N', 'D', 'C', 'E', 'Q', 'G', 'H', 'I', 'L', 'K', 'M', 'F', 'P', 'S', 'T', 'W', 'Y', 'V']
#  15
# [1.2643226051625485, 1.1283218452858408, 0.9282860480181202, 0.7970975431340416, 1.272243168876257, 0.983635420074313, 0.9703104475577136, 0.7619486684343403, 1.203084430565027, 1.6660829713883392, 1.2688273480178338, 0.9784410886101461, 1.5862745677143695, 1.7239989937656162, 0.9995380496073664, 0.6576735681859286, 1.0151511087968241, 1.3679338458530563, 1.253214676537592, 1.324833418532582]
#  ['A', 'R', 'N', 'D', 'C', 'E', 'Q', 'G', 'H', 'I', 'L', 'K', 'M', 'F', 'P', 'S', 'T', 'W', 'Y', 'V']
#
A', 'R', 'N', 'D', 'C', 'E', 'Q', 'G', 'H', 'I', 'L', 'K', 'M', 'F', 'P', 'S', 'T', 'W', 'Y', 'V']
#  6

# %%
def reconstructSequence(dict,data):
  result = []
  for i in range(len(data)):
    currentSeq= ''
    dict_index=list(dict.keys())
    if(i%1000==0):
      print(str(i/len(data)*100)+'%')
    for j in range(len(data[i])):
      row = data[i][j]
      max_value= np.max(row)
      if max_value <= 0.1:
        continue
      #calculate distance
      dist = []
      for key, value in dict.items():
        dist.append(distance.euclidean(dict[key], row))
      currentSeq += dict_index[np.argmin(dist)]
    result.append(currentSeq)
  return result

# %%
def codeMat(data):
  result = []
  print('start codeMat processing')
  for i in range(len(data)):
    result.append(code_seq(newdic,data[i]))
    if(i%1000==0):
      print(str(i/len(data)*100)+'%')
  return result

# %%
reconstructSequence(newdic,dat[:100])

# %%
def compare(dict,data,correct):
  result = []
  num = 0
  total = len(data)
  for i in range(len(data)):
    currentSeq= ''
    dict_index=list(dict.keys())
    if(i%1000==0):
      print(str(i/total*100)+'%')
    for j in range(len(data[i])):
      row = data[i][j]
      max_value= np.max(row)
      if max_value <= 0.1:
        continue
      #calculate distance
      dist = []
      for key, value in dict.items():
        dist.append(distance.euclidean(dict[key], row))
      currentSeq += dict_index[np.argmin(dist)]
    if(currentSeq==correct[j]):
      num += 1
  return num

# %%
compare(newdic,dat,correct_output)
# Out:
# 0.0%
# 3.367570298029971%
# 6.735140596059942%
# 10.102710894089913%
# 13.470281192119884%
# 16.83785149014986%
# 20.205421788179827%
# 23.572992086209798%
# 26.94056238423977%
# 30.308132682269743%
# 33.67570298029972%
# 37.043273278329686%
# 40.41084357635965%
# 43.77841387438963%
# 47.145984172419595%
# 50.51355447044957%
# 53.88112476847954%
# 57.24869506650951%
# 60.61626536453949%
# 63.983835662569454%
# 67.35140596059944%
# 70.7189762586294%
# 74.08654655665937%
# 77.45411685468933%
# 80.8216871527193%
# 84.1892574507493%
# 87.55682774877926%
# 90.92439804680923%
# 94.29196834483919%
# 97.65953864286917%
# 0

# %%
seq1=sample[0][1]
seq1
#cal_distance(newdic,sample[0][1])
# Out:
# array([0.0932311 , 0.12475146, 0.9898873 , 0.11084824, 0.33429328,
#        0.09250832, 0.31490415, 0.08610138, 0.30390126, 0.00269621,
#        0.17761964, 0.02967362, 0.21799266, 0.20830743, 0.31666353],
#       dtype=float32)

# %%
seq2=sample[11][1]
seq2
# Out:
# array([0.09028873, 0.12171932, 0.9898974 , 0.10715594, 0.33057198,
#        0.09065212, 0.3131971 , 0.08410845, 0.3015342 , 0.00274389,
#        0.17471546, 0.02940627, 0.21468134, 0.20447743, 0.31333315],
#       dtype=float32)

# %%
print(cal_distance(newdic,seq1))
print(cal_distance(newdic,seq2))
# Out:
# A
# A

# %%
code_seq(newdic,sample[0])
# Out:
# 'CASSLSSSSSQQLYA'

# %%
code_seq(newdic,sample[99])
# Out:
# C
# A
# S
# S
# L
# S
# S
# S
# S
# S
# Q
# Q
# L
# Y
# A
# 'CASSLSSSSSQQLYA'

# %%
code_seq(newdic,sample[1])
# Out:
# C
# A
# S
# S
# L
# S
# S
# S
# S
# S
# Q
# Q
# L
# Y
# A
# ['C', 'A', 'S', 'S', 'L', 'S', 'S', 'S', 'S', 'S', 'Q', 'Q', 'L', 'Y', 'A']

# %%
code_seq(newdic,sample[9])
# Out:
# ['C', 'A', 'S', 'S', 'L', 'S', 'S', 'S', 'S', 'S', 'Q', 'Q', 'L', 'Y', 'A']

# %%
code=[]
matrix=sample[1]

for i in range(len(matrix)):
  m1=matrix[i]
  code+=cal_distance(newdic,m1)

code
# Out:
# ['A',
#  'F',
#  'F',
#  'F',
#  'A',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'A',
#  'A',
#  'I',
#  'I',
#  'F',
#  'F',
#  'F',
#  'F']

# %%
seq=sample[1]
index_code=list(newdic.keys())
seq_decode = ''
dist=[]
maxcode=[]
for i in range(len(seq)):
  m1=seq[i] # each row w
  #if max(m1) <= 0.1:
   # continue 
  for key, value in newdic.items():
    a1=newdic[key]
    dist.append(distance.euclidean(newdic[key], m1))
\]
  #seq_decode=seq_decode+index_code[np.argmax(dist)]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-61-33ea86256110> in <module>()
#      11     a1=newdic[key]
#      12     dist.append(distance.euclidean(newdic[key], m1))
# ---> 13   maxcode.append(index_code[np.argmax(dist)])
#      14   #seq_decode=seq_decode+index_code[np.argmax(dist)]
#
# IndexError: list index out of range

# %%
maxcode
# Out:
# [0, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 33, 313, 333, 353, 373]

# %%
seq=sample[1]
len(seq)
#cal_distance(newdic,seq)
max(seq[1])
# Out:
# 0.989408

# %%
def seq_reconstruct(seq_array):
  for i in range(len(seq_array)):

# %%
my_file2 = open("/content/drive/MyDrive/DanWei/Copy of TumorCDR3.txt", "r")
content_list2 = my_file2.read().splitlines()

#content_list2=np.array(content_list2)

correct_output=[x for x in content_list2 if len(x)<=19]

# %%
temp_file = np.load('/content/drive/MyDrive/DanWei/Copy of validate_array.npy')
temp_file
# Out:
# array([[[0.00153992, 0.74626714, 0.08051175, ..., 0.429185  ,
#          0.37619844, 0.34518185],
#         [0.0932311 , 0.12475146, 0.9898873 , ..., 0.21799266,
#          0.20830743, 0.31666353],
#         [0.9666149 , 0.66482073, 0.41204515, ..., 0.2994463 ,
#          0.28666407, 0.28645197],
#         ...,
#         [0.00153993, 0.00991142, 0.00747521, ..., 0.01008508,
#          0.00809024, 0.00663861],
#         [0.00125084, 0.00234121, 0.00226621, ..., 0.00251681,
#          0.00206873, 0.00183993],
#         [0.00136809, 0.00170216, 0.00128728, ..., 0.00166269,
#          0.0012867 , 0.00146677]],
#
#        [[0.00164328, 0.7478904 , 0.0805108 , ..., 0.43094915,
#          0.37598193, 0.34417993],
#         [0.09224171, 0.12319089, 0.989408  , ..., 0.21621484,
#          0.20613731, 0.31471512],
#         [0.9661741 , 0.6652579 , 0.41258848, ..., 0.2981643 ,
#          0.2835009 , 0.2854536 ],
#         ...,
#         [0.00163864, 0.01050385, 0.00787834, ..., 0.01041115,
#          0.0085658 , 0.00702032],
#         [0.00133332, 0.00251818, 0.00241548, ..., 0.00262851,
#          0.0021978 , 0.00194652],
#         [0.00146195, 0.00176189, 0.00138614, ..., 0.00173825,
#          0.00135852, 0.00153788]],
#
#        [[0.00182451, 0.74587697, 0.0830553 , ..., 0.4304803 ,
#          0.37804174, 0.34581405],
#         [0.09591877, 0.12665097, 0.9886395 , ..., 0.21943033,
#          0.2099881 , 0.31629688],
#         [0.96437067, 0.6632642 , 0.41413444, ..., 0.2998579 ,
#          0.28761965, 0.28669876],
#         ...,
#         [0.00180963, 0.01140898, 0.00865914, ..., 0.01127031,
#          0.00932987, 0.00767364],
#         [0.00150619, 0.00276036, 0.00268221, ..., 0.00286325,
#          0.00242579, 0.00216264],
#         [0.00163105, 0.00196351, 0.00154108, ..., 0.00192883,
#          0.00152081, 0.00172361]],
#
#        ...,
#
#        [[0.00140899, 0.75214064, 0.07564323, ..., 0.4289359 ,
#          0.37423182, 0.3415201 ],
#         [0.08875278, 0.1189974 , 0.9904883 , ..., 0.21140295,
#          0.20091172, 0.31151587],
#         [0.9681713 , 0.6675398 , 0.4123561 , ..., 0.2962859 ,
#          0.28143305, 0.28146738],
#         ...,
#         [0.00139815, 0.0095149 , 0.00704577, ..., 0.00949392,
#          0.00768969, 0.00627797],
#         [0.00115251, 0.00220822, 0.00208962, ..., 0.00225346,
#          0.00189405, 0.00167034],
#         [0.00125194, 0.001472  , 0.00119211, ..., 0.0014891 ,
#          0.0011537 , 0.00133419]],
#
#        [[0.00176232, 0.74737394, 0.08130527, ..., 0.4306648 ,
#          0.37787345, 0.34531024],
#         [0.09352552, 0.12485783, 0.9889787 , ..., 0.2178291 ,
#          0.20811044, 0.31490588],
#         [0.9651675 , 0.66494393, 0.41255298, ..., 0.29956737,
#          0.28600237, 0.28619882],
#         ...,
#         [0.00175573, 0.010902  , 0.00823037, ..., 0.01104152,
#          0.00894388, 0.00733958],
#         [0.00143981, 0.00268296, 0.00259232, ..., 0.00279871,
#          0.00234536, 0.00207945],
#         [0.00157793, 0.00189421, 0.00148762, ..., 0.00187734,
#          0.00145793, 0.00167591]],
#
#        [[0.00138321, 0.74941176, 0.07871027, ..., 0.42995194,
#          0.37672633, 0.3440146 ],
#         [0.09066382, 0.12256306, 0.99060214, ..., 0.21589498,
#          0.20604172, 0.3142681 ],
#         [0.9679483 , 0.66568667, 0.41113037, ..., 0.29844478,
#          0.28459686, 0.28541002],
#         ...,
#         [0.00138188, 0.00933152, 0.0068385 , ..., 0.00945798,
#          0.00749828, 0.00612034],
#         [0.00110025, 0.00213232, 0.00207196, ..., 0.00226769,
#          0.00184357, 0.0016244 ],
#         [0.0012311 , 0.00149322, 0.00115095, ..., 0.00148867,
#          0.00113296, 0.00131273]]], dtype=float32)
